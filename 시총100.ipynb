# %%
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
from pprint import pprint

def get_market_cap_top100():
    top_100 = {}
    for page in range(1, 3):  # 두 번의 요청을 수행하여 100개 항목 가져오기
        url = f'https://finance.naver.com/sise/sise_market_sum.naver?sosok=0&page={page}'
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        stocks = soup.select('.type_2 tbody tr')

        for stock in stocks:
            cells = stock.find_all('td')
            if len(cells) >= 7:
                name = cells[1].text.strip()
                code = cells[1].a['href'].split('=')[-1]
                top_100[name] = {"code": code}
    return top_100

top_100 = get_market_cap_top100()
pprint(top_100, sort_dicts=False)
# Out:
# {'삼성전자': {'code': '005930'},
#  'SK하이닉스': {'code': '000660'},
#  'LG에너지솔루션': {'code': '373220'},
#  '현대차': {'code': '005380'},
#  '삼성바이오로직스': {'code': '207940'},
#  '삼성전자우': {'code': '005935'},
#  '기아': {'code': '000270'},
#  '셀트리온': {'code': '068270'},
#  'KB금융': {'code': '105560'},
#  'POSCO홀딩스': {'code': '005490'},
#  'NAVER': {'code': '035420'},
#  '삼성SDI': {'code': '006400'},
#  'LG화학': {'code': '051910'},
#  '삼성물산': {'code': '028260'},
#  '신한지주': {'code': '055550'},
#  '현대모비스': {'code': '012330'},
#  '포스코퓨처엠': {'code': '003670'},
#  '카카오': {'code': '035720'},
#  '하나금융지주': {'code': '086790'},
#  'LG전자': {'code': '066570'},
#  '삼성생명': {'code': '032830'},
#  '삼성화재': {'code': '000810'},
#  '한미반도체': {'code': '042700'},
#  '메리츠금융지주': {'code': '138040'},
#  '두산에너빌리티': {'code': '034020'},
#  'SK': {'code': '034730'},
#  'LG': {'code': '003550'},
#  '한국전력': {'code': '015760'},
#  'HMM': {'code': '011200'},
#  '크래프톤': {'code': '259960'},
#  '삼성에스디에스': {'code': '018260'},
#  '삼성전기': {'code': '009150'},
#  'HD현대중공업': {'code': '329180'},
#  '아모레퍼시픽': {'code': '090430'},
#  '고려아연': {'code': '010130'},
#  '기업은행': {'code': '024110'},
#  'SK텔레콤': {'code': '017670'},
#  'KT&G': {'code': '033780'},
#  'HD현대일렉트릭': {'code': '267260'},
#  '카카오뱅크': {'code': '323410'},
#  '우리금융지주': {'code': '316140'},
#  'SK스퀘어': {'code': '402340'},
#  '한화에어로스페이스': {'code': '012450'},
#  'SK이노베이션': {'code': '096770'},
#  'KT': {'code': '030200'},
#  'HD한국조선해양': {'code': '009540'},
#  '한화오션': {'code': '042660'},
#  'KODEX CD금리액티브(합성)': {'code': '459580'},
#  '하이브': {'code': '352820'},
#  '삼성중공업': {'code': '010140'},
#  'S-Oil': {'code': '010950'},
#  '대한항공': {'code': '003490'},
#  '포스코인터내셔널': {'code': '047050'},
#  'DB손해보험': {'code': '005830'},
#  'TIGER CD금리투자KIS(합성)': {'code': '357870'},
#  '현대글로비스': {'code': '086280'},
#  'SK바이오팜': {'code': '326030'},
#  'LG생활건강': {'code': '051900'},
#  'LS ELECTRIC': {'code': '010120'},
#  'KODEX 200': {'code': '069500'},
#  'LG이노텍': {'code': '011070'},
#  'HD현대마린솔루션': {'code': '443060'},
#  '두산밥캣': {'code': '241560'},
#  '엘앤에프': {'code': '066970'},
#  '유한양행': {'code': '000100'},
#  '맥쿼리인프라': {'code': '088980'},
#  '현대차2우B': {'code': '005387'},
#  '에코프로머티': {'code': '450080'},
#  'LS': {'code': '006260'},
#  '한국타이어앤테크놀로지': {'code': '161390'},
#  'HD현대': {'code': '267250'},
#  '한화솔루션': {'code': '009830'},
#  '포스코DX': {'code': '022100'},
#  'SKC': {'code': '011790'},
#  'CJ제일제당': {'code': '097950'},
#  '넷마블': {'code': '251270'},
#  'KODEX KOFR금리액티브(합성)': {'code': '423160'},
#  '한국항공우주': {'code': '047810'},
#  '코스모신소재': {'code': '005070'},
#  'LG디스플레이': {'code': '034220'},
#  '롯데케미칼': {'code': '011170'},
#  '금양': {'code': '001570'},
#  '두산로보틱스': {'code': '454910'},
#  '삼성카드': {'code': '029780'},
#  '삼성E&A': {'code': '028050'},
#  '미래에셋증권': {'code': '006800'},
#  '한진칼': {'code': '180640'},
#  'LG유플러스': {'code': '032640'},
#  '엔씨소프트': {'code': '036570'},
#  '카카오페이': {'code': '377300'},
#  '코웨이': {'code': '021240'},
#  '효성중공업': {'code': '298040'},
#  '금호석유': {'code': '011780'},
#  '현대오토에버': {'code': '307950'},
#  'GS': {'code': '078930'},
#  'CJ': {'code': '001040'},
#  'NH투자증권': {'code': '005940'},
#  '삼양식품': {'code': '003230'},
#  'SK바이오사이언스': {'code': '302440'},
#  '현대제철': {'code': '004020'}}
